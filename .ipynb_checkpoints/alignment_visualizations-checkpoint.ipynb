# %% [markdown]
# # Alignment Visualizations

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

import numpy as np
import matplotlib.pyplot as plt

# import matplotlib
# matplotlib.use("pgf")
# matplotlib.rcParams.update({
#     "pgf.texsystem": "pdflatex",
#     'font.family': 'serif',
#     'text.usetex': True,
#     'pgf.rcfonts': False,
# })

import seaborn as sns
sns.set(rc={'figure.figsize':(11,4)})
import pandas as pd
import re
from ipywidgets import interactive, interact, fixed, interact_manual, SelectMultiple
from IPython.display import display

import ipywidgets as widgets

# %%
color_picker = widgets.ColorPicker(
    concise=True,
    description='Background color:',
    value='#efefef',
)
color_picker
# Out:
# ColorPicker(value='#efefef', concise=True, description='Background color:')

# %%
print(color_picker.value)
# Out:
# #cc0000

# %%
range_slider = widgets.FloatRangeSlider(
    value=[-1., +1.],
    min=-5., max=+5., step=0.1,
    description='xlim:',
    readout_format='.1f',
)
range_slider
# Out:
# FloatRangeSlider(value=(-1.0, 1.0), description='xlim:', max=5.0, min=-5.0, readout_format='.1f')

# %%
items = [widgets.widgets.Accordion(children=[widgets.IntSlider(), widgets.Text()], titles=('Slider', 'Text')) for i in range(8)]
widgets.GridBox(items, layout=widgets.Layout(grid_template_columns="repeat(5, 150px)"))
# Out:
# GridBox(children=(Accordion(children=(IntSlider(value=0), Text(value=''))), Accordion(children=(IntSlider(valu…

# %%
accordion = widgets.Accordion(children=[widgets.IntSlider(), widgets.Text()], titles=('Slider', 'Text'))
accordion
# Out:
# Accordion(children=(IntSlider(value=0), Text(value='')))

# %%
print(accordion.children[1].value)
# Out:
# asdöflja

# %%
button = widgets.Button(description="Click Me!")
output = widgets.Output()

display(button, output)

def on_button_clicked(b):
    with output:
        print("Button clicked.")
print("hello")
button.on_click(on_button_clicked)
# Out:
# Button(description='Click Me!', style=ButtonStyle())
# Output()
# hello
# Hi
# Hi
# Hi
# Hi
